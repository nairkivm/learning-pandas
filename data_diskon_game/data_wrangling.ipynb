# %%
# Import packages
import requests
import pandas as pd

# %% [markdown]
# - Diberikan sebuah data API yang berisikan tentang list game apa saja yang sedang diskon saat ini `https://www.cheapshark.com/api/1.0/deals?upperPrice=30&pageSize=1000`
# - Cek status code dari API tersebut

# %%
respons = requests.get("https://www.cheapshark.com/api/1.0/deals?upperPrice=30&pageSize=1000")

respons.status_code
# Out:
# 200

# %% [markdown]
# - Ubah data API tersebut menjadi bentuk **JSON**

# %%
rawData = respons.json()
rawData
# Out:
# [{'internalName': 'SAILFORTH',
#   'title': 'Sail Forth',
#   'metacriticLink': '/game/sail-forth/',
#   'dealID': 'sz546Tl6B1DiwBR5j9oG50afCXd9qJ4x2nxDWDESmSI%3D',
#   'storeID': '25',
#   'gameID': '255026',
#   'salePrice': '0.00',
#   'normalPrice': '19.99',
#   'isOnSale': '1',
#   'savings': '100.000000',
#   'metacriticScore': '0',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '93',
#   'steamRatingCount': '357',
#   'steamAppID': '1031460',
#   'releaseDate': 1671580800,
#   'lastChange': 1704995897,
#   'dealRating': '10.0',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/1031460/capsule_sm_120.jpg?t=1705017320'},
#  {'internalName': 'IMMORTALSFENYXRISINGGOLDEDITION',
#   'title': 'Immortals Fenyx Rising Gold Edition',
#   'metacriticLink': None,
#   'dealID': 'ydp4QlvyTAEIdcZYHdLdFAF3G9n5l903xfXDNEvIR3o%3D',
#   'storeID': '27',
#   'gameID': '233320',
#   'salePrice': '13.99',
#   'normalPrice': '99.99',
#   'isOnSale': '1',
#   'savings': '86.008601',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705277354,
#   'dealRating': '10.0',
#   'thumb': 'https://hb.imgix.net/99ac330cd8194385c47c92209bc3b5d3725d2af7.jpg?auto=compress,format&fit=crop&h=84&w=135&s=ef77404730cb25cebedec08b2faeea3b'},
#  {'internalName': 'VRALLY4ULTIMATEEDITION',
#   'title': 'V-Rally 4 Ultimate Edition',
#   'metacriticLink': None,
#   'dealID': 'WdIHAsWfT%2BEQvi4Zth94wcNmn4ICr%2BVTBOgjv3huwMc%3D',
#   'storeID': '30',
#   'gameID': '191972',
#   'salePrice': '6.99',
#   'normalPrice': '69.99',
#   'isOnSale': '1',
#   'savings': '90.012859',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1704889637,
#   'dealRating': '10.0',
#   'thumb': 'https://images.greenmangaming.com/f1dbed643b8f44fea59e3334f0f23894/a7de63071b59454c9bc2dd04d10fdebc.jpg'},
#  {'internalName': 'BACK4BLOODDELUXEEDITION',
#   'title': 'Back 4 Blood: Deluxe Edition',
#   'metacriticLink': None,
#   'dealID': 'C%2FLZ1Q3ZykTfIohgmSyA39broCoTzd%2Fzh2go9IHtW8I%3D',
#   'storeID': '33',
#   'gameID': '235448',
#   'salePrice': '15.84',
#   'normalPrice': '89.99',
#   'isOnSale': '1',
#   'savings': '82.398044',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705405727,
#   'dealRating': '10.0',
#   'thumb': 'https://sttc.gamersgate.com/images/product/back-4-blood-deluxe-edition/cover-180-267524.jpg'},
#  {'internalName': 'BACK4BLOODULTIMATEEDITION',
#   'title': 'Back 4 Blood: Ultimate Edition',
#   'metacriticLink': None,
#   'dealID': 'DQbcm8Wnzz3RkefkFOIyHv4L5D2YdWEzSJOdrQX8wnM%3D',
#   'storeID': '33',
#   'gameID': '235447',
#   'salePrice': '17.60',
#   'normalPrice': '99.99',
#   'isOnSale': '1',
#   'savings': '82.398240',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705405727,
#   'dealRating': '10.0',
#   'thumb': 'https://sttc.gamersgate.com/images/product/back-4-blood-ultimate-edition/cover-180-91231d.jpg'},
#  {'internalName': 'DISCOELYSIUMTHEFINALCUT',
#   'title': 'Disco Elysium - The Final Cut',
#   'metacriticLink': '/game/disco-elysium-the-final-cut/',
#   'dealID': 'g9c%2BkOWn2%2Bj5FOnUTGqrs%2Bm9N5y7eAhXMD51w0clRaM%3D',
#   'storeID': '27',
#   'gameID': '227942',
#   'salePrice': '8.99',
#   'normalPrice': '39.99',
#   'isOnSale': '1',
#   'savings': '77.519380',
#   'metacriticScore': '97',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '93',
#   'steamRatingCount': '80374',
#   'steamAppID': '632470',
#   'releaseDate': 1617062400,
#   'lastChange': 1705486413,
#   'dealRating': '10.0',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/632470/capsule_sm_120.jpg?t=1698833230'},
#  {'internalName': 'FORHONORCOMPLETEEDITION',
#   'title': 'For Honor Complete Edition',
#   'metacriticLink': None,
#   'dealID': '64hswox6mbqueYEMXg5nABgy0%2FF23%2BuKtBIl7Tp1xyo%3D',
#   'storeID': '3',
#   'gameID': '196575',
#   'salePrice': '17.20',
#   'normalPrice': '99.99',
#   'isOnSale': '1',
#   'savings': '82.798280',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705315851,
#   'dealRating': '10.0',
#   'thumb': 'https://images.greenmangaming.com/478bffac631745c8b48889764353141e/8292a65b0d7c44f2a9081338902447cc.jpg'},
#  {'internalName': 'ASSASSINSCREEDODYSSEYDELUXEEDITION',
#   'title': "Assassin's Creed Odyssey - Deluxe Edition",
#   'metacriticLink': None,
#   'dealID': 'j46CiZP1igYcQ4VBE9PsYhpLCPCNmeQ%2FpH3sbAfUsBs%3D',
#   'storeID': '27',
#   'gameID': '188229',
#   'salePrice': '14.92',
#   'normalPrice': '79.99',
#   'isOnSale': '1',
#   'savings': '81.347668',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705277271,
#   'dealRating': '10.0',
#   'thumb': 'https://images.greenmangaming.com/85f64a5bdd2045fcae1dbfaa2b03b28e/18f26e2f95974e6ab4f8181434d4dd00.jpg'},
#  {'internalName': 'MYHEROONESJUSTICE2ULTIMATEEDITION',
#   'title': 'MY HERO ONES JUSTICE 2 Ultimate Edition',
#   'metacriticLink': None,
#   'dealID': 'bJKNt5Tpy8IH4Af8%2FzGpr9dKkgoJCDujW5hd2uMf964%3D',
#   'storeID': '3',
#   'gameID': '274423',
#   'salePrice': '17.20',
#   'normalPrice': '79.99',
#   'isOnSale': '1',
#   'savings': '78.497312',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705494147,
#   'dealRating': '10.0',
#   'thumb': 'https://images.greenmangaming.com/943fe15861a14874a03e5f4b83f2cbb6/0a02c24abfcb433e87dfa7c11632eb1d.jpg'},
#  {'internalName': 'WATCHDOGSLEGIONGOLDEDITION',
#   'title': 'Watch Dogs: Legion Gold Edition',
#   'metacriticLink': None,
#   'dealID': 'g3eCjnYWaon69lWfWLPTMWZXkhFuNCL7j2ffOnE9hLk%3D',
#   'storeID': '13',
#   'gameID': '202373',
#   'salePrice': '20.00',
#   'normalPrice': '99.99',
#   'isOnSale': '1',
#   'savings': '79.998000',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705482900,
#   'dealRating': '10.0',
#   'thumb': 'https://hb.imgix.net/5fa544ab5435535c247224d10fb6221a94809367.jpg?auto=compress,format&fit=crop&h=84&w=135&s=64691808b8704b76a97ec82ecd039eb0'},
#  {'internalName': 'GHOSTRECONBREAKPOINTGOLDEDITION',
#   'title': 'Ghost Recon Breakpoint Gold Edition',
#   'metacriticLink': None,
#   'dealID': 'K%2FSq0%2FLclKRLoUeZ345jVfTJex8akNn9mg0hL00dUU4%3D',
#   'storeID': '13',
#   'gameID': '243453',
#   'salePrice': '20.00',
#   'normalPrice': '99.99',
#   'isOnSale': '1',
#   'savings': '79.998000',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705482893,
#   'dealRating': '10.0',
#   'thumb': 'https://store.ubisoft.com/dw/image/v2/ABBS_PRD/on/demandware.static/-/Sites-masterCatalog/default/dw4b86e642/images/large/5cc81f606b54a4cd3c0e9d1b.jpg?sw=197&amp;sh=261&amp;sm=fit'},
#  {'internalName': 'DEUSEXHUMANREVOLUTIONDIRECTORSCUT',
#   'title': "Deus Ex: Human Revolution - Director's Cut",
#   'metacriticLink': '/game/deus-ex-human-revolution-directors-cut/',
#   'dealID': 'QQev7bRmvxf8GIe2kvTFSw5n989i%2FaTYbEhwhkBBPiw%3D',
#   'storeID': '3',
#   'gameID': '102249',
#   'salePrice': '2.55',
#   'normalPrice': '19.99',
#   'isOnSale': '1',
#   'savings': '87.243622',
#   'metacriticScore': '91',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '92',
#   'steamRatingCount': '22350',
#   'steamAppID': '238010',
#   'releaseDate': 1382400000,
#   'lastChange': 1705318491,
#   'dealRating': '9.9',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/238010/capsule_sm_120.jpg?t=1700763527'},
#  {'internalName': 'ASSASSINSCREEDODYSSEYGOLDEDITION',
#   'title': 'Assassins Creed Odyssey Gold Edition',
#   'metacriticLink': None,
#   'dealID': '%2Bj1YG%2BiaAw3mvcPG1Ko1mnx0uYXwcTdcSc49lJ4m48U%3D',
#   'storeID': '27',
#   'gameID': '188216',
#   'salePrice': '18.50',
#   'normalPrice': '99.99',
#   'isOnSale': '1',
#   'savings': '81.498150',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705277271,
#   'dealRating': '9.9',
#   'thumb': 'https://images.greenmangaming.com/b0279bf8df8a426987e1c4abaeffb03a/45ef97623d6246b8a367d7a3370d4a17.jpg'},
#  {'internalName': 'ASSASSINSCREEDORIGINSGOLDEDITION',
#   'title': 'Assassins Creed Origins Gold Edition',
#   'metacriticLink': None,
#   'dealID': 'ed2T3JtmWfyE4UMDjpqECpUEPpbpGdDpmJC0k9geRJg%3D',
#   'storeID': '27',
#   'gameID': '170045',
#   'salePrice': '18.88',
#   'normalPrice': '99.99',
#   'isOnSale': '1',
#   'savings': '81.118112',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705277258,
#   'dealRating': '9.9',
#   'thumb': 'https://images.greenmangaming.com/e6797d37de1243a1a79b5fede824bda3/da9b336eecab4f57b33543893d426051.jpg'},
#  {'internalName': 'DISCOELYSIUMTHEFINALCUT',
#   'title': 'Disco Elysium - The Final Cut',
#   'metacriticLink': '/game/disco-elysium-the-final-cut/',
#   'dealID': 'Zr6Qh66JezQZoHa7vNBD2et8thCQntN5nxYy228tdiQ%3D',
#   'storeID': '33',
#   'gameID': '227942',
#   'salePrice': '10.00',
#   'normalPrice': '39.99',
#   'isOnSale': '1',
#   'savings': '74.993748',
#   'metacriticScore': '97',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '93',
#   'steamRatingCount': '80374',
#   'steamAppID': '632470',
#   'releaseDate': 1617062400,
#   'lastChange': 1705454333,
#   'dealRating': '9.9',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/632470/capsule_sm_120.jpg?t=1698833230'},
#  {'internalName': 'DISCOELYSIUMTHEFINALCUT',
#   'title': 'Disco Elysium - The Final Cut',
#   'metacriticLink': '/game/disco-elysium-the-final-cut/',
#   'dealID': 'FWo2qDF5TJDvgtCXgavBlBYnsiZ7ULEutfsn3RSfI1Y%3D',
#   'storeID': '2',
#   'gameID': '227942',
#   'salePrice': '10.00',
#   'normalPrice': '39.99',
#   'isOnSale': '1',
#   'savings': '74.993748',
#   'metacriticScore': '97',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '93',
#   'steamRatingCount': '80374',
#   'steamAppID': '632470',
#   'releaseDate': 1617062400,
#   'lastChange': 1705456512,
#   'dealRating': '9.9',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/632470/capsule_sm_120.jpg?t=1698833230'},
#  {'internalName': 'GHOSTRECONWILDLANDSULTIMATEEDITION',
#   'title': 'Ghost Recon Wildlands Ultimate Edition',
#   'metacriticLink': None,
#   'dealID': '4bTt5B2DF1Ufw9u1kwVpcZQIcJyAM6IXPc9gYhaFhgI%3D',
#   'storeID': '13',
#   'gameID': '243454',
#   'salePrice': '24.00',
#   'normalPrice': '119.99',
#   'isOnSale': '1',
#   'savings': '79.998333',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705482894,
#   'dealRating': '9.9',
#   'thumb': 'https://store.ubisoft.com/dw/image/v2/ABBS_PRD/on/demandware.static/-/Sites-masterCatalog/en_US/dw09223723/images/large/5b969c88ca1a64033f76fa29.jpg?sw=197&amp;sh=261&amp;sm=fit'},
#  {'internalName': 'ASSASSINSCREEDODYSSEYULTIMATEEDITION',
#   'title': 'Assassins Creed Odyssey Ultimate Edition',
#   'metacriticLink': None,
#   'dealID': 'x5zBRZ4ShbYQz2G%2BQFkyKvDug4StFdBGWCIucUSHJPI%3D',
#   'storeID': '13',
#   'gameID': '188217',
#   'salePrice': '24.00',
#   'normalPrice': '119.99',
#   'isOnSale': '1',
#   'savings': '79.998333',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705482893,
#   'dealRating': '9.9',
#   'thumb': 'https://images.greenmangaming.com/5586046eb67a48f186b1abaa86d276f1/85bcc60d3c074a518533c565b9e51058.jpg'},
#  {'internalName': 'ASSASSINSCREEDODYSSEYULTIMATEEDITION',
#   'title': 'Assassins Creed Odyssey Ultimate Edition',
#   'metacriticLink': None,
#   'dealID': 'UwiMbIvtQ7zMU1PoXSUs96G2OweD6gOkEcIqulOmpGU%3D',
#   'storeID': '27',
#   'gameID': '188217',
#   'salePrice': '21.91',
#   'normalPrice': '119.99',
#   'isOnSale': '1',
#   'savings': '81.740145',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705277271,
#   'dealRating': '9.8',
#   'thumb': 'https://images.greenmangaming.com/5586046eb67a48f186b1abaa86d276f1/85bcc60d3c074a518533c565b9e51058.jpg'},
#  {'internalName': 'ROOMTOGROW',
#   'title': 'Room to Grow',
#   'metacriticLink': '/game/room-to-grow/',
#   'dealID': 'WoEU0IkVBtXU5PjuBPjEwvf6yzVdD2exiVt3N2PUjzA%3D',
#   'storeID': '1',
#   'gameID': '226652',
#   'salePrice': '3.29',
#   'normalPrice': '9.99',
#   'isOnSale': '1',
#   'savings': '67.067067',
#   'metacriticScore': '0',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '96',
#   'steamRatingCount': '141',
#   'steamAppID': '1471960',
#   'releaseDate': 1735603200,
#   'lastChange': 1705346988,
#   'dealRating': '9.8',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/1471960/capsule_sm_120.jpg?t=1628313954'},
#  {'internalName': 'INJUSTICE2',
#   'title': 'Injustice 2',
#   'metacriticLink': '/game/injustice-2/',
#   'dealID': 'eygDOeEHscshfLYg%2FpK%2BcBkzV0aAxCv7qG4%2FaPSviy0%3D',
#   'storeID': '3',
#   'gameID': '174988',
#   'salePrice': '3.90',
#   'normalPrice': '49.99',
#   'isOnSale': '1',
#   'savings': '92.198440',
#   'metacriticScore': '86',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '86',
#   'steamRatingCount': '13795',
#   'steamAppID': '627270',
#   'releaseDate': 1512000000,
#   'lastChange': 1705313571,
#   'dealRating': '9.8',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/627270/capsule_sm_120.jpg?t=1699983966'},
#  {'internalName': 'EGOSOFTCOLLECTION',
#   'title': 'Egosoft Collection',
#   'metacriticLink': None,
#   'dealID': '4ULWVn7y7r3lDsGPrz626CbCK0IDgViVUmdWOT6NcR0%3D',
#   'storeID': '2',
#   'gameID': '151359',
#   'salePrice': '18.00',
#   'normalPrice': '89.99',
#   'isOnSale': '1',
#   'savings': '79.997778',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705274922,
#   'dealRating': '9.7',
#   'thumb': 'https://sttc.gamersgate.com/images/product/egosoft-collection/cover-180-9675c7.jpg'},
#  {'internalName': 'THIEFIITHEMETALAGE',
#   'title': 'Thief II: The Metal Age',
#   'metacriticLink': '/game/thief-ii-the-metal-age/',
#   'dealID': 'xK7Wbkh5hs1o%2BHwHxngcxY7EtkYXZD%2FyE3kpfwrTpiU%3D',
#   'storeID': '3',
#   'gameID': '87640',
#   'salePrice': '0.83',
#   'normalPrice': '6.99',
#   'isOnSale': '1',
#   'savings': '88.125894',
#   'metacriticScore': '87',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '94',
#   'steamRatingCount': '1580',
#   'steamAppID': '211740',
#   'releaseDate': 951782400,
#   'lastChange': 1705318499,
#   'dealRating': '9.7',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/211740/capsule_sm_120.jpg?t=1681398228'},
#  {'internalName': 'WHENSKILIFTSGOWRONG',
#   'title': 'When Ski Lifts Go Wrong',
#   'metacriticLink': '/game/when-ski-lifts-go-wrong/',
#   'dealID': '1068%2Fpl1FYU1QV2j55esOK2m5JqZ2df3%2Fy%2BS5T92fXc%3D',
#   'storeID': '2',
#   'gameID': '194665',
#   'salePrice': '1.31',
#   'normalPrice': '14.99',
#   'isOnSale': '1',
#   'savings': '91.260841',
#   'metacriticScore': '80',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '87',
#   'steamRatingCount': '463',
#   'steamAppID': '638000',
#   'releaseDate': 1548201600,
#   'lastChange': 1705491553,
#   'dealRating': '9.7',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/638000/capsule_sm_120.jpg?t=1668073718'},
#  {'internalName': 'ULTRASTREETFIGHTERIV',
#   'title': 'Ultra Street Fighter IV',
#   'metacriticLink': '/game/ultra-street-fighter-iv/',
#   'dealID': 'AapiljSH7HK3vulPX7UD2U%2ByeVImV453leqeVZjqqRU%3D',
#   'storeID': '30',
#   'gameID': '113336',
#   'salePrice': '3.15',
#   'normalPrice': '29.99',
#   'isOnSale': '1',
#   'savings': '89.496499',
#   'metacriticScore': '82',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '90',
#   'steamRatingCount': '8823',
#   'steamAppID': '45760',
#   'releaseDate': 1407369600,
#   'lastChange': 1705487394,
#   'dealRating': '9.6',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/45760/capsule_sm_120.jpg?t=1687765428'},
#  {'internalName': 'ASSASSINSCREEDVALHALLADELUXEEDITION',
#   'title': 'Assassins Creed Valhalla Deluxe Edition',
#   'metacriticLink': None,
#   'dealID': 'OlDiN6mlw%2F%2FljKCJ4fASkxJd2NhOwNQBFpBU00XwI54%3D',
#   'storeID': '27',
#   'gameID': '233316',
#   'salePrice': '18.50',
#   'normalPrice': '79.99',
#   'isOnSale': '1',
#   'savings': '76.872109',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705277352,
#   'dealRating': '9.6',
#   'thumb': 'https://images.greenmangaming.com/760a3a77cfb44210aef4b4d4aa6b8227/6ce0dda072cf4a78bf166ca85a9c7450.jpg'},
#  {'internalName': 'THENEXTPENELOPE',
#   'title': 'The Next Penelope',
#   'metacriticLink': '/game/the-next-penelope/',
#   'dealID': 'iwoMzvld2An65XYBjvhYusGV%2BD3WnWOOlmIDKAUCGCg%3D',
#   'storeID': '30',
#   'gameID': '141090',
#   'salePrice': '1.29',
#   'normalPrice': '12.99',
#   'isOnSale': '1',
#   'savings': '90.069284',
#   'metacriticScore': '82',
#   'steamRatingText': 'Mostly Positive',
#   'steamRatingPercent': '73',
#   'steamRatingCount': '125',
#   'steamAppID': '332250',
#   'releaseDate': 1421798400,
#   'lastChange': 1705400881,
#   'dealRating': '9.6',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/332250/capsule_sm_120.jpg?t=1602168342'},
#  {'internalName': 'WHENSKILIFTSGOWRONG',
#   'title': 'When Ski Lifts Go Wrong',
#   'metacriticLink': '/game/when-ski-lifts-go-wrong/',
#   'dealID': 'IhmJLXn3LYHKf0AOhW6skqrMGvaVkIiQdiurM5e97Oo%3D',
#   'storeID': '23',
#   'gameID': '194665',
#   'salePrice': '1.50',
#   'normalPrice': '14.99',
#   'isOnSale': '1',
#   'savings': '89.993329',
#   'metacriticScore': '80',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '87',
#   'steamRatingCount': '463',
#   'steamAppID': '638000',
#   'releaseDate': 1548201600,
#   'lastChange': 1705489357,
#   'dealRating': '9.6',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/638000/capsule_sm_120.jpg?t=1668073718'},
#  {'internalName': 'WHENSKILIFTSGOWRONG',
#   'title': 'When Ski Lifts Go Wrong',
#   'metacriticLink': '/game/when-ski-lifts-go-wrong/',
#   'dealID': '2gRyumvsJP8mKQxoJg4Jp1kCDwnivqoJTa498z7NZGI%3D',
#   'storeID': '35',
#   'gameID': '194665',
#   'salePrice': '1.50',
#   'normalPrice': '14.99',
#   'isOnSale': '1',
#   'savings': '89.993329',
#   'metacriticScore': '80',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '87',
#   'steamRatingCount': '463',
#   'steamAppID': '638000',
#   'releaseDate': 1548201600,
#   'lastChange': 1705489332,
#   'dealRating': '9.6',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/638000/capsule_sm_120.jpg?t=1668073718'},
#  {'internalName': 'GUILTYGEARXRDSIGN',
#   'title': 'GUILTY GEAR Xrd -SIGN-',
#   'metacriticLink': '/game/guilty-gear-xrd-sign/',
#   'dealID': 'P%2FcFOx8GxyKj%2Bni6hzXfQkGsNQnNU0mumfP%2BcbgNMvA%3D',
#   'storeID': '1',
#   'gameID': '147415',
#   'salePrice': '3.89',
#   'normalPrice': '29.99',
#   'isOnSale': '1',
#   'savings': '87.029010',
#   'metacriticScore': '84',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '91',
#   'steamRatingCount': '2011',
#   'steamAppID': '376300',
#   'releaseDate': 1449619200,
#   'lastChange': 1705487959,
#   'dealRating': '9.5',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/376300/capsule_sm_120.jpg?t=1671009243'},
#  {'internalName': 'BACK4BLOODDELUXE',
#   'title': 'Back 4 Blood Deluxe',
#   'metacriticLink': None,
#   'dealID': 'VZIXcT4ZExpzfB8Y6uHEdtVg53p7SdWc4pUoIBBADbY%3D',
#   'storeID': '30',
#   'gameID': '265037',
#   'salePrice': '14.99',
#   'normalPrice': '89.99',
#   'isOnSale': '1',
#   'savings': '83.342594',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1704889672,
#   'dealRating': '9.5',
#   'thumb': 'https://www.indiegalacdn.com/get_store_img?img=store-img_game/games/medium/924970_deluxe.jpg&s=medium'},
#  {'internalName': 'GOTHAMKNIGHTSDELUXEEDITION',
#   'title': 'Gotham Knights Deluxe Edition',
#   'metacriticLink': None,
#   'dealID': 'hLZlILH1tkPoIYdL8tO6T4mS%2BSzjh8azFmJOgmoLDQo%3D',
#   'storeID': '30',
#   'gameID': '246054',
#   'salePrice': '14.99',
#   'normalPrice': '79.99',
#   'isOnSale': '1',
#   'savings': '81.260158',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1704966893,
#   'dealRating': '9.5',
#   'thumb': 'https://sttc.gamersgate.com/images/product/gotham-knights-deluxe-edition/cover-180-e1de87.jpg'},
#  {'internalName': 'CANDLE',
#   'title': 'Candle',
#   'metacriticLink': '/game/candle/',
#   'dealID': 'db2UsPUHqIkMPI94f82QBrYP50DUpNVMo7cP3mfgdiE%3D',
#   'storeID': '7',
#   'gameID': '155405',
#   'salePrice': '0.99',
#   'normalPrice': '9.99',
#   'isOnSale': '1',
#   'savings': '90.090090',
#   'metacriticScore': '80',
#   'steamRatingText': 'Mostly Positive',
#   'steamRatingPercent': '77',
#   'steamRatingCount': '798',
#   'steamAppID': '420060',
#   'releaseDate': 1478822400,
#   'lastChange': 1705415843,
#   'dealRating': '9.5',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/420060/capsule_sm_120.jpg?t=1562676294'},
#  {'internalName': 'FLYN',
#   'title': "Fly'N",
#   'metacriticLink': '/game/flyn/',
#   'dealID': 'pY0buvvHBuYrWTyXgs9tf60kmX3pL%2FVaff6oewNKHkw%3D',
#   'storeID': '30',
#   'gameID': '93749',
#   'salePrice': '0.99',
#   'normalPrice': '9.99',
#   'isOnSale': '1',
#   'savings': '90.090090',
#   'metacriticScore': '80',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '90',
#   'steamRatingCount': '277',
#   'steamAppID': '223730',
#   'releaseDate': 1352419200,
#   'lastChange': 1705400825,
#   'dealRating': '9.5',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/223730/capsule_sm_120.jpg?t=1531722646'},
#  {'internalName': 'ULTRASTREETFIGHTERIV',
#   'title': 'Ultra Street Fighter IV',
#   'metacriticLink': '/game/ultra-street-fighter-iv/',
#   'dealID': 'zpHYW5N55oAf9yqavVirqrtSgnKZtdvvotShoBuGL%2Bk%3D',
#   'storeID': '34',
#   'gameID': '113336',
#   'salePrice': '3.60',
#   'normalPrice': '29.99',
#   'isOnSale': '1',
#   'savings': '87.995999',
#   'metacriticScore': '82',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '90',
#   'steamRatingCount': '8823',
#   'steamAppID': '45760',
#   'releaseDate': 1407369600,
#   'lastChange': 1705453245,
#   'dealRating': '9.5',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/45760/capsule_sm_120.jpg?t=1687765428'},
#  {'internalName': 'ASSASSINSCREEDVALHALLARAGNARKEDITION',
#   'title': 'Assassins Creed Valhalla - Ragnark Edition',
#   'metacriticLink': None,
#   'dealID': 'Rc2INyLS%2BJ74hDJMPDvzGUFD55uLn9lEw%2Bvo4M5Mcco%3D',
#   'storeID': '27',
#   'gameID': '241106',
#   'salePrice': '22.50',
#   'normalPrice': '99.99',
#   'isOnSale': '1',
#   'savings': '77.497750',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705277360,
#   'dealRating': '9.4',
#   'thumb': 'https://hb.imgix.net/55aeda639e1c330e90ff6c62259e4b4d56485cd8.jpg?auto=compress,format&fit=crop&h=84&w=135&s=45d86e01287bfdc3740950705e1ecd82'},
#  {'internalName': 'FARCRY6GOLDEDITION',
#   'title': 'Far Cry 6 Gold Edition',
#   'metacriticLink': None,
#   'dealID': 'aEnbFXudyt%2FRFVe7j2V%2Bj78qQEGBEbQueWJ4VwGhA7o%3D',
#   'storeID': '13',
#   'gameID': '233327',
#   'salePrice': '25.00',
#   'normalPrice': '99.99',
#   'isOnSale': '1',
#   'savings': '74.997500',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1705482894,
#   'dealRating': '9.4',
#   'thumb': 'https://images.greenmangaming.com/7ddf07c794a6429aa389518d771b17ff/e4dee4866e5f4ac8a6127ec4207946d2.jpg'},
#  {'internalName': 'BACK4BLOODULTIMATE',
#   'title': 'Back 4 Blood Ultimate',
#   'metacriticLink': None,
#   'dealID': 'Pvdpj%2BZhHhwey6QSI4HS5hRkdu9OcfhWciR57vlzTMA%3D',
#   'storeID': '30',
#   'gameID': '265038',
#   'salePrice': '16.99',
#   'normalPrice': '99.99',
#   'isOnSale': '1',
#   'savings': '83.008301',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1704889672,
#   'dealRating': '9.4',
#   'thumb': 'https://www.indiegalacdn.com/get_store_img?img=store-img_game/games/medium/924970_ultimate.jpg&s=medium'},
#  {'internalName': 'ANARCUTE',
#   'title': 'Anarcute',
#   'metacriticLink': '/game/anarcute/',
#   'dealID': '9xWoqWp8LSYeS5FkRFMXq9VzmHnHXamB9l1WIUsfNnc%3D',
#   'storeID': '30',
#   'gameID': '154826',
#   'salePrice': '1.49',
#   'normalPrice': '14.99',
#   'isOnSale': '1',
#   'savings': '90.060040',
#   'metacriticScore': '79',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '92',
#   'steamRatingCount': '426',
#   'steamAppID': '390720',
#   'releaseDate': 1468281600,
#   'lastChange': 1705400912,
#   'dealRating': '9.4',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/390720/capsule_sm_120.jpg?t=1592923256'},
#  {'internalName': 'WANDERLUSTTRAVELSTORIES',
#   'title': 'Wanderlust Travel Stories',
#   'metacriticLink': '/game/wanderlust-travel-stories/',
#   'dealID': 'O7SzyZP8I%2FfSymrQkJ91fpblqYL9MxoXMqTLXem8QKo%3D',
#   'storeID': '30',
#   'gameID': '203269',
#   'salePrice': '1.49',
#   'normalPrice': '14.99',
#   'isOnSale': '1',
#   'savings': '90.060040',
#   'metacriticScore': '79',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '88',
#   'steamRatingCount': '90',
#   'steamAppID': '1051410',
#   'releaseDate': 1569456000,
#   'lastChange': 1705400717,
#   'dealRating': '9.4',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/1051410/capsule_sm_120.jpg?t=1678963931'},
#  {'internalName': 'ULTRASTREETFIGHTERIV',
#   'title': 'Ultra Street Fighter IV',
#   'metacriticLink': '/game/ultra-street-fighter-iv/',
#   'dealID': 'u0rYUI7Bafax3EQ2IjuhuUTmKFwL%2FDI42%2FSli2p7xZQ%3D',
#   'storeID': '23',
#   'gameID': '113336',
#   'salePrice': '3.90',
#   'normalPrice': '29.99',
#   'isOnSale': '1',
#   'savings': '86.995665',
#   'metacriticScore': '82',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '90',
#   'steamRatingCount': '8823',
#   'steamAppID': '45760',
#   'releaseDate': 1407369600,
#   'lastChange': 1705486896,
#   'dealRating': '9.4',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/45760/capsule_sm_120.jpg?t=1687765428'},
#  {'internalName': 'ULTRASTREETFIGHTERIV',
#   'title': 'Ultra Street Fighter IV',
#   'metacriticLink': '/game/ultra-street-fighter-iv/',
#   'dealID': 'BkYhQSSUU%2FMl1ONvgQw7VkWognM3oiTsBxz%2FapvukSI%3D',
#   'storeID': '24',
#   'gameID': '113336',
#   'salePrice': '3.90',
#   'normalPrice': '29.99',
#   'isOnSale': '1',
#   'savings': '86.995665',
#   'metacriticScore': '82',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '90',
#   'steamRatingCount': '8823',
#   'steamAppID': '45760',
#   'releaseDate': 1407369600,
#   'lastChange': 1705461107,
#   'dealRating': '9.4',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/45760/capsule_sm_120.jpg?t=1687765428'},
#  {'internalName': 'MONSTERSLAYERS',
#   'title': 'Monster Slayers',
#   'metacriticLink': '/game/monster-slayers/',
#   'dealID': 'Uqg0XVBn2QpUPg0tFzp9DkM9Pl%2FvuqpbtHpPtElZJ%2BY%3D',
#   'storeID': '1',
#   'gameID': '167601',
#   'salePrice': '1.34',
#   'normalPrice': '8.99',
#   'isOnSale': '1',
#   'savings': '85.094549',
#   'metacriticScore': '86',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '80',
#   'steamRatingCount': '763',
#   'steamAppID': '496620',
#   'releaseDate': 1490227200,
#   'lastChange': 1705346952,
#   'dealRating': '9.4',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/496620/capsule_sm_120.jpg?t=1630517695'},
#  {'internalName': 'WOLFENSTEINIITHENEWCOLOSSUS',
#   'title': 'Wolfenstein II: The New Colossus',
#   'metacriticLink': '/game/wolfenstein-ii-the-new-colossus/',
#   'dealID': 'esTlL4z9bsy8mR%2FWllR0t75AA358eJzH4m8OFyKu3FU%3D',
#   'storeID': '3',
#   'gameID': '170049',
#   'salePrice': '5.10',
#   'normalPrice': '39.99',
#   'isOnSale': '1',
#   'savings': '87.246812',
#   'metacriticScore': '86',
#   'steamRatingText': 'Mostly Positive',
#   'steamRatingPercent': '79',
#   'steamRatingCount': '26537',
#   'steamAppID': '612880',
#   'releaseDate': 1509062400,
#   'lastChange': 1705316137,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/612880/capsule_sm_120.jpg?t=1691683256'},
#  {'internalName': 'DEUSEXHUMANREVOLUTIONDIRECTORSCUT',
#   'title': "Deus Ex: Human Revolution - Director's Cut",
#   'metacriticLink': '/game/deus-ex-human-revolution-directors-cut/',
#   'dealID': 'CHSUkUA5Qsd%2Fz%2BBJ6a95p7hGCN0oyXK83Mg9G5yhnyY%3D',
#   'storeID': '7',
#   'gameID': '102249',
#   'salePrice': '2.99',
#   'normalPrice': '19.99',
#   'isOnSale': '1',
#   'savings': '85.042521',
#   'metacriticScore': '91',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '92',
#   'steamRatingCount': '22350',
#   'steamAppID': '238010',
#   'releaseDate': 1382400000,
#   'lastChange': 1705070155,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/238010/capsule_sm_120.jpg?t=1700763527'},
#  {'internalName': 'IRONYCURTAINFROMMATRYOSHKAWITHLOVE',
#   'title': 'Irony Curtain: From Matryoshka with Love',
#   'metacriticLink': '/game/irony-curtain-from-matryoshka-with-love/',
#   'dealID': 'NOMvAIPfoQ7jtWpkkBnWUhLEO8YKWwGfkdUmGYK22oE%3D',
#   'storeID': '7',
#   'gameID': '201096',
#   'salePrice': '1.99',
#   'normalPrice': '19.99',
#   'isOnSale': '1',
#   'savings': '90.045023',
#   'metacriticScore': '81',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '87',
#   'steamRatingCount': '332',
#   'steamAppID': '866190',
#   'releaseDate': 1557964800,
#   'lastChange': 1705329404,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/866190/capsule_sm_120.jpg?t=1668560833'},
#  {'internalName': 'GOTHAMKNIGHTSDELUXEEDITION',
#   'title': 'Gotham Knights Deluxe Edition',
#   'metacriticLink': None,
#   'dealID': 'CDRsDh1lsUDjJuvwOerd%2Fu5jUXMCjXOMQUEpZN7jUjw%3D',
#   'storeID': '34',
#   'gameID': '246054',
#   'salePrice': '15.20',
#   'normalPrice': '79.99',
#   'isOnSale': '1',
#   'savings': '80.997625',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1704922522,
#   'dealRating': '9.3',
#   'thumb': 'https://sttc.gamersgate.com/images/product/gotham-knights-deluxe-edition/cover-180-e1de87.jpg'},
#  {'internalName': 'DROPSY',
#   'title': 'Dropsy',
#   'metacriticLink': '/game/dropsy/',
#   'dealID': 'JccRVtjMm%2FuBEkG%2Ffmie5Uct1e8QTaxIj06QZ5ySrSY%3D',
#   'storeID': '7',
#   'gameID': '145148',
#   'salePrice': '0.99',
#   'normalPrice': '9.99',
#   'isOnSale': '1',
#   'savings': '90.090090',
#   'metacriticScore': '80',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '93',
#   'steamRatingCount': '1382',
#   'steamAppID': '274350',
#   'releaseDate': 1441843200,
#   'lastChange': 1705329470,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/274350/capsule_sm_120.jpg?t=1667383598'},
#  {'internalName': 'ROCKOFAGES3MAKEANDBREAK',
#   'title': 'Rock of Ages 3: Make and Break',
#   'metacriticLink': '/game/rock-of-ages-3-make-and-break/',
#   'dealID': 'vqYgeqe0SiH2SsE2zQ3zapxniPzE3E4AWOe2U1S5Kzs%3D',
#   'storeID': '3',
#   'gameID': '218458',
#   'salePrice': '1.35',
#   'normalPrice': '29.99',
#   'isOnSale': '1',
#   'savings': '95.498499',
#   'metacriticScore': '72',
#   'steamRatingText': 'Mostly Positive',
#   'steamRatingPercent': '76',
#   'steamRatingCount': '733',
#   'steamAppID': '1101360',
#   'releaseDate': 1595289600,
#   'lastChange': 1705315980,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/1101360/capsule_sm_120.jpg?t=1599239331'},
#  {'internalName': 'ULTRASTREETFIGHTERIV',
#   'title': 'Ultra Street Fighter IV',
#   'metacriticLink': '/game/ultra-street-fighter-iv/',
#   'dealID': '2k1iHZIVamMaeIML72kmPdWGf4NQ8jot82VwCgAExQg%3D',
#   'storeID': '27',
#   'gameID': '113336',
#   'salePrice': '3.20',
#   'normalPrice': '29.99',
#   'isOnSale': '1',
#   'savings': '89.329777',
#   'metacriticScore': '82',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '90',
#   'steamRatingCount': '8823',
#   'steamAppID': '45760',
#   'releaseDate': 1407369600,
#   'lastChange': 1705310296,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/45760/capsule_sm_120.jpg?t=1687765428'},
#  {'internalName': 'TESLAGRAD',
#   'title': 'Teslagrad',
#   'metacriticLink': '/game/teslagrad/',
#   'dealID': 'Cv2CaEIkDEtOZ4GKG%2BQ0CfW02bjBEX8ZE21NUr9inNM%3D',
#   'storeID': '7',
#   'gameID': '104043',
#   'salePrice': '0.99',
#   'normalPrice': '9.99',
#   'isOnSale': '1',
#   'savings': '90.090090',
#   'metacriticScore': '77',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '84',
#   'steamRatingCount': '1633',
#   'steamAppID': '249590',
#   'releaseDate': 1386892800,
#   'lastChange': 1705415880,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/249590/capsule_sm_120.jpg?t=1679368918'},
#  {'internalName': 'DRAGONSDOGMADARKARISEN',
#   'title': 'Dragons Dogma: Dark Arisen',
#   'metacriticLink': '/game/dragons-dogma-dark-arisen/',
#   'dealID': 'u5%2BqhoR6SDgcAVAWDFRnp3ixY6WW4uyIciCz%2F0m%2F17w%3D',
#   'storeID': '30',
#   'gameID': '146236',
#   'salePrice': '3.99',
#   'normalPrice': '29.99',
#   'isOnSale': '1',
#   'savings': '86.695565',
#   'metacriticScore': '81',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '89',
#   'steamRatingCount': '29656',
#   'steamAppID': '367500',
#   'releaseDate': 1452816000,
#   'lastChange': 1705487361,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/367500/capsule_sm_120.jpg?t=1701395331'},
#  {'internalName': 'DARKFUTUREBLOODREDSTATES',
#   'title': 'Dark Future: Blood Red States',
#   'metacriticLink': '/game/dark-future-blood-red-states/',
#   'dealID': 'KlRycTf08ZW0w0DReX8XcUlqdVdLV10IDCB3c6hgvHY%3D',
#   'storeID': '30',
#   'gameID': '201617',
#   'salePrice': '2.49',
#   'normalPrice': '24.99',
#   'isOnSale': '1',
#   'savings': '90.036014',
#   'metacriticScore': '78',
#   'steamRatingText': 'Mostly Positive',
#   'steamRatingPercent': '73',
#   'steamRatingCount': '211',
#   'steamAppID': '370870',
#   'releaseDate': 1626739200,
#   'lastChange': 1705400904,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/370870/capsule_sm_120.jpg?t=1668079498'},
#  {'internalName': 'BADDREAMCOMA',
#   'title': 'Bad Dream: Coma',
#   'metacriticLink': '/game/bad-dream-coma/',
#   'dealID': 'ZKZdAvI3UHaMPYAg0bURT7wf%2F%2FH6dh2Ita%2Fht3qdoJM%3D',
#   'storeID': '1',
#   'gameID': '177327',
#   'salePrice': '0.89',
#   'normalPrice': '8.99',
#   'isOnSale': '1',
#   'savings': '90.100111',
#   'metacriticScore': '79',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '91',
#   'steamRatingCount': '1730',
#   'steamAppID': '538070',
#   'releaseDate': 1489017600,
#   'lastChange': 1705345272,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/538070/capsule_sm_120.jpg?t=1664464452'},
#  {'internalName': 'RACETHESUN',
#   'title': 'Race the Sun',
#   'metacriticLink': '/game/race-the-sun/',
#   'dealID': '9gZSq0gZE5d%2BHL4FsZmwDGB3SYhyRd0742JnPKQ1PjI%3D',
#   'storeID': '7',
#   'gameID': '102638',
#   'salePrice': '0.99',
#   'normalPrice': '9.99',
#   'isOnSale': '1',
#   'savings': '90.090090',
#   'metacriticScore': '79',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '94',
#   'steamRatingCount': '1891',
#   'steamAppID': '253030',
#   'releaseDate': 1376870400,
#   'lastChange': 1705329490,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/253030/capsule_sm_120.jpg?t=1685019618'},
#  {'internalName': 'SEMBLANCE',
#   'title': 'Semblance',
#   'metacriticLink': '/game/semblance/',
#   'dealID': '%2BhIe51fqt40VxsF47rhvcnf%2BQh%2BP5CSA2lp39sEo3Mw%3D',
#   'storeID': '7',
#   'gameID': '189551',
#   'salePrice': '0.99',
#   'normalPrice': '9.99',
#   'isOnSale': '1',
#   'savings': '90.090090',
#   'metacriticScore': '79',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '85',
#   'steamRatingCount': '261',
#   'steamAppID': '700160',
#   'releaseDate': 1532390400,
#   'lastChange': 1705326855,
#   'dealRating': '9.3',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/700160/capsule_sm_120.jpg?t=1680797529'},
#  {'internalName': 'FIGMENT',
#   'title': 'Figment',
#   'metacriticLink': '/game/figment/',
#   'dealID': '0mkMwC%2Fjmml39ifPBRufx6gp7Oah1Ycwr2jsS8rOprA%3D',
#   'storeID': '30',
#   'gameID': '173455',
#   'salePrice': '1.99',
#   'normalPrice': '19.99',
#   'isOnSale': '1',
#   'savings': '90.045023',
#   'metacriticScore': '77',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '87',
#   'steamRatingCount': '987',
#   'steamAppID': '493540',
#   'releaseDate': 1506038400,
#   'lastChange': 1705400949,
#   'dealRating': '9.2',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/493540/capsule_sm_120.jpg?t=1697539050'},
#  {'internalName': 'BACK4BLOODDELUXEEDITION',
#   'title': 'Back 4 Blood: Deluxe Edition',
#   'metacriticLink': None,
#   'dealID': 'gmOVMOUHoAf58uIuzQ50vJ4icFXBp2jjtu1IgOfmsBo%3D',
#   'storeID': '34',
#   'gameID': '235448',
#   'salePrice': '17.10',
#   'normalPrice': '89.99',
#   'isOnSale': '1',
#   'savings': '80.997889',
#   'metacriticScore': '0',
#   'steamRatingText': None,
#   'steamRatingPercent': '0',
#   'steamRatingCount': '0',
#   'steamAppID': None,
#   'releaseDate': 0,
#   'lastChange': 1704922536,
#   'dealRating': '9.2',
#   'thumb': 'https://sttc.gamersgate.com/images/product/back-4-blood-deluxe-edition/cover-180-267524.jpg'},
#  {'internalName': 'ANOMALYWARZONEEARTH',
#   'title': 'Anomaly: Warzone Earth',
#   'metacriticLink': '/game/anomaly-warzone-earth/',
#   'dealID': 'XOYard89AJhM%2BioC7Cc50MyY9xVZtCIttfcZaNymw38%3D',
#   'storeID': '1',
#   'gameID': '343',
#   'salePrice': '1.09',
#   'normalPrice': '9.99',
#   'isOnSale': '1',
#   'savings': '89.089089',
#   'metacriticScore': '80',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '85',
#   'steamRatingCount': '896',
#   'steamAppID': '91200',
#   'releaseDate': 1302220800,
#   'lastChange': 1705347051,
#   'dealRating': '9.2',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/91200/capsule_sm_120.jpg?t=1634818526'},
#  {'internalName': 'VOLGARRTHEVIKING',
#   'title': 'Volgarr the Viking',
#   'metacriticLink': '/game/volgarr-the-viking/',
#   'dealID': 'bynDVTMfuK7ySPJgFFKrduqz4nuAgELCsBs6z0q7kOs%3D',
#   'storeID': '7',
#   'gameID': '101616',
#   'salePrice': '0.99',
#   'normalPrice': '9.99',
#   'isOnSale': '1',
#   'savings': '90.090090',
#   'metacriticScore': '76',
#   'steamRatingText': 'Very Positive',
#   'steamRatingPercent': '84',
#   'steamRatingCount': '1559',
#   'steamAppID': '247240',
#   'releaseDate': 1379030400,
#   'lastChange': 1705415882,
#   'dealRating': '9.2',
#   'thumb': 'https://cdn.cloudflare.steamstatic.com/steam/apps/247240/capsule_sm_120.jpg?t=1666987693'}]

# %% [markdown]
# - Ubah data JSON tersebut menjadi bentuk DataFrame dengan menggunakan `pandas`
# - Setelah itu tampilkan data yang sudah diconvert menjadi DataFrame

# %%
rawGameDataFrame = pd.DataFrame(rawData)
rawGameDataFrame
# Out:
#                             internalName  \
# 0                              SAILFORTH
# 1        IMMORTALSFENYXRISINGGOLDEDITION
# 2                 VRALLY4ULTIMATEEDITION
# 3                BACK4BLOODDELUXEEDITION
# 4              BACK4BLOODULTIMATEEDITION
# 5                DISCOELYSIUMTHEFINALCUT
# 6                FORHONORCOMPLETEEDITION
# 7     ASSASSINSCREEDODYSSEYDELUXEEDITION
# 8      MYHEROONESJUSTICE2ULTIMATEEDITION
# 9             WATCHDOGSLEGIONGOLDEDITION
# 10       GHOSTRECONBREAKPOINTGOLDEDITION
# 11     DEUSEXHUMANREVOLUTIONDIRECTORSCUT
# 12      ASSASSINSCREEDODYSSEYGOLDEDITION
# 13      ASSASSINSCREEDORIGINSGOLDEDITION
# 14               DISCOELYSIUMTHEFINALCUT
# 15               DISCOELYSIUMTHEFINALCUT
# 16    GHOSTRECONWILDLANDSULTIMATEEDITION
# 17  ASSASSINSCREEDODYSSEYULTIMATEEDITION
# 18  ASSASSINSCREEDODYSSEYULTIMATEEDITION
# 19                            ROOMTOGROW
# 20                            INJUSTICE2
# 21                     EGOSOFTCOLLECTION
# 22                    THIEFIITHEMETALAGE
# 23                   WHENSKILIFTSGOWRONG
# 24                  ULTRASTREETFIGHTERIV
# 25   ASSASSINSCREEDVALHALLADELUXEEDITION
# 26                       THENEXTPENELOPE
# 27                   WHENSKILIFTSGOWRONG
# 28                   WHENSKILIFTSGOWRONG
# 29                     GUILTYGEARXRDSIGN
# 30                      BACK4BLOODDELUXE
# 31            GOTHAMKNIGHTSDELUXEEDITION
# 32                                CANDLE
# 33                                  FLYN
# 34                  ULTRASTREETFIGHTERIV
# 35  ASSASSINSCREEDVALHALLARAGNARKEDITION
# 36                    FARCRY6GOLDEDITION
# 37                    BACK4BLOODULTIMATE
# 38                              ANARCUTE
# 39               WANDERLUSTTRAVELSTORIES
# 40                  ULTRASTREETFIGHTERIV
# 41                  ULTRASTREETFIGHTERIV
# 42                        MONSTERSLAYERS
# 43           WOLFENSTEINIITHENEWCOLOSSUS
# 44     DEUSEXHUMANREVOLUTIONDIRECTORSCUT
# 45    IRONYCURTAINFROMMATRYOSHKAWITHLOVE
# 46            GOTHAMKNIGHTSDELUXEEDITION
# 47                                DROPSY
# 48               ROCKOFAGES3MAKEANDBREAK
# 49                  ULTRASTREETFIGHTERIV
# 50                             TESLAGRAD
# 51                DRAGONSDOGMADARKARISEN
# 52              DARKFUTUREBLOODREDSTATES
# 53                          BADDREAMCOMA
# 54                            RACETHESUN
# 55                             SEMBLANCE
# 56                               FIGMENT
# 57               BACK4BLOODDELUXEEDITION
# 58                   ANOMALYWARZONEEARTH
# 59                      VOLGARRTHEVIKING
#
#                                          title  \
# 0                                   Sail Forth
# 1          Immortals Fenyx Rising Gold Edition
# 2                   V-Rally 4 Ultimate Edition
# 3                 Back 4 Blood: Deluxe Edition
# 4               Back 4 Blood: Ultimate Edition
# 5                Disco Elysium - The Final Cut
# 6                   For Honor Complete Edition
# 7    Assassin's Creed Odyssey - Deluxe Edition
# 8      MY HERO ONES JUSTICE 2 Ultimate Edition
# 9              Watch Dogs: Legion Gold Edition
# 10         Ghost Recon Breakpoint Gold Edition
# 11  Deus Ex: Human Revolution - Director's Cut
# 12        Assassins Creed Odyssey Gold Edition
# 13        Assassins Creed Origins Gold Edition
# 14               Disco Elysium - The Final Cut
# 15               Disco Elysium - The Final Cut
# 16      Ghost Recon Wildlands Ultimate Edition
# 17    Assassins Creed Odyssey Ultimate Edition
# 18    Assassins Creed Odyssey Ultimate Edition
# 19                                Room to Grow
# 20                                 Injustice 2
# 21                          Egosoft Collection
# 22                     Thief II: The Metal Age
# 23                     When Ski Lifts Go Wrong
# 24                     Ultra Street Fighter IV
# 25     Assassins Creed Valhalla Deluxe Edition
# 26                           The Next Penelope
# 27                     When Ski Lifts Go Wrong
# 28                     When Ski Lifts Go Wrong
# 29                      GUILTY GEAR Xrd -SIGN-
# 30                         Back 4 Blood Deluxe
# 31               Gotham Knights Deluxe Edition
# 32                                      Candle
# 33                                       Fly'N
# 34                     Ultra Street Fighter IV
# 35  Assassins Creed Valhalla - Ragnark Edition
# 36                      Far Cry 6 Gold Edition
# 37                       Back 4 Blood Ultimate
# 38                                    Anarcute
# 39                   Wanderlust Travel Stories
# 40                     Ultra Street Fighter IV
# 41                     Ultra Street Fighter IV
# 42                             Monster Slayers
# 43            Wolfenstein II: The New Colossus
# 44  Deus Ex: Human Revolution - Director's Cut
# 45    Irony Curtain: From Matryoshka with Love
# 46               Gotham Knights Deluxe Edition
# 47                                      Dropsy
# 48              Rock of Ages 3: Make and Break
# 49                     Ultra Street Fighter IV
# 50                                   Teslagrad
# 51                  Dragons Dogma: Dark Arisen
# 52               Dark Future: Blood Red States
# 53                             Bad Dream: Coma
# 54                                Race the Sun
# 55                                   Semblance
# 56                                     Figment
# 57                Back 4 Blood: Deluxe Edition
# 58                      Anomaly: Warzone Earth
# 59                          Volgarr the Viking
#
#                                     metacriticLink  \
# 0                                /game/sail-forth/
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                             None
# 5               /game/disco-elysium-the-final-cut/
# 6                                             None
# 7                                             None
# 8                                             None
# 9                                             None
# 10                                            None
# 11   /game/deus-ex-human-revolution-directors-cut/
# 12                                            None
# 13                                            None
# 14              /game/disco-elysium-the-final-cut/
# 15              /game/disco-elysium-the-final-cut/
# 16                                            None
# 17                                            None
# 18                                            None
# 19                             /game/room-to-grow/
# 20                              /game/injustice-2/
# 21                                            None
# 22                   /game/thief-ii-the-metal-age/
# 23                  /game/when-ski-lifts-go-wrong/
# 24                  /game/ultra-street-fighter-iv/
# 25                                            None
# 26                        /game/the-next-penelope/
# 27                  /game/when-ski-lifts-go-wrong/
# 28                  /game/when-ski-lifts-go-wrong/
# 29                     /game/guilty-gear-xrd-sign/
# 30                                            None
# 31                                            None
# 32                                   /game/candle/
# 33                                     /game/flyn/
# 34                  /game/ultra-street-fighter-iv/
# 35                                            None
# 36                                            None
# 37                                            None
# 38                                 /game/anarcute/
# 39                /game/wanderlust-travel-stories/
# 40                  /game/ultra-street-fighter-iv/
# 41                  /game/ultra-street-fighter-iv/
# 42                          /game/monster-slayers/
# 43          /game/wolfenstein-ii-the-new-colossus/
# 44   /game/deus-ex-human-revolution-directors-cut/
# 45  /game/irony-curtain-from-matryoshka-with-love/
# 46                                            None
# 47                                   /game/dropsy/
# 48            /game/rock-of-ages-3-make-and-break/
# 49                  /game/ultra-street-fighter-iv/
# 50                                /game/teslagrad/
# 51                /game/dragons-dogma-dark-arisen/
# 52             /game/dark-future-blood-red-states/
# 53                           /game/bad-dream-coma/
# 54                             /game/race-the-sun/
# 55                                /game/semblance/
# 56                                  /game/figment/
# 57                                            None
# 58                    /game/anomaly-warzone-earth/
# 59                       /game/volgarr-the-viking/
#
#                                                dealID storeID  gameID  \
# 0      sz546Tl6B1DiwBR5j9oG50afCXd9qJ4x2nxDWDESmSI%3D      25  255026
# 1      ydp4QlvyTAEIdcZYHdLdFAF3G9n5l903xfXDNEvIR3o%3D      27  233320
# 2   WdIHAsWfT%2BEQvi4Zth94wcNmn4ICr%2BVTBOgjv3huwM...      30  191972
# 3   C%2FLZ1Q3ZykTfIohgmSyA39broCoTzd%2Fzh2go9IHtW8...      33  235448
# 4      DQbcm8Wnzz3RkefkFOIyHv4L5D2YdWEzSJOdrQX8wnM%3D      33  235447
# 5   g9c%2BkOWn2%2Bj5FOnUTGqrs%2Bm9N5y7eAhXMD51w0cl...      27  227942
# 6   64hswox6mbqueYEMXg5nABgy0%2FF23%2BuKtBIl7Tp1xy...       3  196575
# 7    j46CiZP1igYcQ4VBE9PsYhpLCPCNmeQ%2FpH3sbAfUsBs%3D      27  188229
# 8    bJKNt5Tpy8IH4Af8%2FzGpr9dKkgoJCDujW5hd2uMf964%3D       3  274423
# 9      g3eCjnYWaon69lWfWLPTMWZXkhFuNCL7j2ffOnE9hLk%3D      13  202373
# 10  K%2FSq0%2FLclKRLoUeZ345jVfTJex8akNn9mg0hL00dUU...      13  243453
# 11   QQev7bRmvxf8GIe2kvTFSw5n989i%2FaTYbEhwhkBBPiw%3D       3  102249
# 12  %2Bj1YG%2BiaAw3mvcPG1Ko1mnx0uYXwcTdcSc49lJ4m48...      27  188216
# 13     ed2T3JtmWfyE4UMDjpqECpUEPpbpGdDpmJC0k9geRJg%3D      27  170045
# 14     Zr6Qh66JezQZoHa7vNBD2et8thCQntN5nxYy228tdiQ%3D      33  227942
# 15     FWo2qDF5TJDvgtCXgavBlBYnsiZ7ULEutfsn3RSfI1Y%3D       2  227942
# 16     4bTt5B2DF1Ufw9u1kwVpcZQIcJyAM6IXPc9gYhaFhgI%3D      13  243454
# 17   x5zBRZ4ShbYQz2G%2BQFkyKvDug4StFdBGWCIucUSHJPI%3D      13  188217
# 18     UwiMbIvtQ7zMU1PoXSUs96G2OweD6gOkEcIqulOmpGU%3D      27  188217
# 19     WoEU0IkVBtXU5PjuBPjEwvf6yzVdD2exiVt3N2PUjzA%3D       1  226652
# 20  eygDOeEHscshfLYg%2FpK%2BcBkzV0aAxCv7qG4%2FaPSv...       3  174988
# 21     4ULWVn7y7r3lDsGPrz626CbCK0IDgViVUmdWOT6NcR0%3D       2  151359
# 22  xK7Wbkh5hs1o%2BHwHxngcxY7EtkYXZD%2FyE3kpfwrTpi...       3   87640
# 23  1068%2Fpl1FYU1QV2j55esOK2m5JqZ2df3%2Fy%2BS5T92...       2  194665
# 24   AapiljSH7HK3vulPX7UD2U%2ByeVImV453leqeVZjqqRU%3D      30  113336
# 25  OlDiN6mlw%2F%2FljKCJ4fASkxJd2NhOwNQBFpBU00XwI5...      27  233316
# 26   iwoMzvld2An65XYBjvhYusGV%2BD3WnWOOlmIDKAUCGCg%3D      30  141090
# 27     IhmJLXn3LYHKf0AOhW6skqrMGvaVkIiQdiurM5e97Oo%3D      23  194665
# 28     2gRyumvsJP8mKQxoJg4Jp1kCDwnivqoJTa498z7NZGI%3D      35  194665
# 29  P%2FcFOx8GxyKj%2Bni6hzXfQkGsNQnNU0mumfP%2BcbgN...       1  147415
# 30     VZIXcT4ZExpzfB8Y6uHEdtVg53p7SdWc4pUoIBBADbY%3D      30  265037
# 31   hLZlILH1tkPoIYdL8tO6T4mS%2BSzjh8azFmJOgmoLDQo%3D      30  246054
# 32     db2UsPUHqIkMPI94f82QBrYP50DUpNVMo7cP3mfgdiE%3D       7  155405
# 33   pY0buvvHBuYrWTyXgs9tf60kmX3pL%2FVaff6oewNKHkw%3D      30   93749
# 34   zpHYW5N55oAf9yqavVirqrtSgnKZtdvvotShoBuGL%2Bk%3D      34  113336
# 35  Rc2INyLS%2BJ74hDJMPDvzGUFD55uLn9lEw%2Bvo4M5Mcc...      27  241106
# 36  aEnbFXudyt%2FRFVe7j2V%2Bj78qQEGBEbQueWJ4VwGhA7...      13  233327
# 37   Pvdpj%2BZhHhwey6QSI4HS5hRkdu9OcfhWciR57vlzTMA%3D      30  265038
# 38     9xWoqWp8LSYeS5FkRFMXq9VzmHnHXamB9l1WIUsfNnc%3D      30  154826
# 39   O7SzyZP8I%2FfSymrQkJ91fpblqYL9MxoXMqTLXem8QKo%3D      30  203269
# 40  u0rYUI7Bafax3EQ2IjuhuUTmKFwL%2FDI42%2FSli2p7xZ...      23  113336
# 41  BkYhQSSUU%2FMl1ONvgQw7VkWognM3oiTsBxz%2FapvukS...      24  113336
# 42  Uqg0XVBn2QpUPg0tFzp9DkM9Pl%2FvuqpbtHpPtElZJ%2B...       1  167601
# 43   esTlL4z9bsy8mR%2FWllR0t75AA358eJzH4m8OFyKu3FU%3D       3  170049
# 44  CHSUkUA5Qsd%2Fz%2BBJ6a95p7hGCN0oyXK83Mg9G5yhny...       7  102249
# 45     NOMvAIPfoQ7jtWpkkBnWUhLEO8YKWwGfkdUmGYK22oE%3D       7  201096
# 46   CDRsDh1lsUDjJuvwOerd%2Fu5jUXMCjXOMQUEpZN7jUjw%3D      34  246054
# 47  JccRVtjMm%2FuBEkG%2Ffmie5Uct1e8QTaxIj06QZ5ySrS...       7  145148
# 48     vqYgeqe0SiH2SsE2zQ3zapxniPzE3E4AWOe2U1S5Kzs%3D       3  218458
# 49     2k1iHZIVamMaeIML72kmPdWGf4NQ8jot82VwCgAExQg%3D      27  113336
# 50   Cv2CaEIkDEtOZ4GKG%2BQ0CfW02bjBEX8ZE21NUr9inNM%3D       7  104043
# 51  u5%2BqhoR6SDgcAVAWDFRnp3ixY6WW4uyIciCz%2F0m%2F...      30  146236
# 52     KlRycTf08ZW0w0DReX8XcUlqdVdLV10IDCB3c6hgvHY%3D      30  201617
# 53  ZKZdAvI3UHaMPYAg0bURT7wf%2F%2FH6dh2Ita%2Fht3qd...       1  177327
# 54   9gZSq0gZE5d%2BHL4FsZmwDGB3SYhyRd0742JnPKQ1PjI%3D       7  102638
# 55  %2BhIe51fqt40VxsF47rhvcnf%2BQh%2BP5CSA2lp39sEo...       7  189551
# 56   0mkMwC%2Fjmml39ifPBRufx6gp7Oah1Ycwr2jsS8rOprA%3D      30  173455
# 57     gmOVMOUHoAf58uIuzQ50vJ4icFXBp2jjtu1IgOfmsBo%3D      34  235448
# 58   XOYard89AJhM%2BioC7Cc50MyY9xVZtCIttfcZaNymw38%3D       1     343
# 59     bynDVTMfuK7ySPJgFFKrduqz4nuAgELCsBs6z0q7kOs%3D       7  101616
#
#    salePrice normalPrice isOnSale     savings metacriticScore  \
# 0       0.00       19.99        1  100.000000               0
# 1      13.99       99.99        1   86.008601               0
# 2       6.99       69.99        1   90.012859               0
# 3      15.84       89.99        1   82.398044               0
# 4      17.60       99.99        1   82.398240               0
# 5       8.99       39.99        1   77.519380              97
# 6      17.20       99.99        1   82.798280               0
# 7      14.92       79.99        1   81.347668               0
# 8      17.20       79.99        1   78.497312               0
# 9      20.00       99.99        1   79.998000               0
# 10     20.00       99.99        1   79.998000               0
# 11      2.55       19.99        1   87.243622              91
# 12     18.50       99.99        1   81.498150               0
# 13     18.88       99.99        1   81.118112               0
# 14     10.00       39.99        1   74.993748              97
# 15     10.00       39.99        1   74.993748              97
# 16     24.00      119.99        1   79.998333               0
# 17     24.00      119.99        1   79.998333               0
# 18     21.91      119.99        1   81.740145               0
# 19      3.29        9.99        1   67.067067               0
# 20      3.90       49.99        1   92.198440              86
# 21     18.00       89.99        1   79.997778               0
# 22      0.83        6.99        1   88.125894              87
# 23      1.31       14.99        1   91.260841              80
# 24      3.15       29.99        1   89.496499              82
# 25     18.50       79.99        1   76.872109               0
# 26      1.29       12.99        1   90.069284              82
# 27      1.50       14.99        1   89.993329              80
# 28      1.50       14.99        1   89.993329              80
# 29      3.89       29.99        1   87.029010              84
# 30     14.99       89.99        1   83.342594               0
# 31     14.99       79.99        1   81.260158               0
# 32      0.99        9.99        1   90.090090              80
# 33      0.99        9.99        1   90.090090              80
# 34      3.60       29.99        1   87.995999              82
# 35     22.50       99.99        1   77.497750               0
# 36     25.00       99.99        1   74.997500               0
# 37     16.99       99.99        1   83.008301               0
# 38      1.49       14.99        1   90.060040              79
# 39      1.49       14.99        1   90.060040              79
# 40      3.90       29.99        1   86.995665              82
# 41      3.90       29.99        1   86.995665              82
# 42      1.34        8.99        1   85.094549              86
# 43      5.10       39.99        1   87.246812              86
# 44      2.99       19.99        1   85.042521              91
# 45      1.99       19.99        1   90.045023              81
# 46     15.20       79.99        1   80.997625               0
# 47      0.99        9.99        1   90.090090              80
# 48      1.35       29.99        1   95.498499              72
# 49      3.20       29.99        1   89.329777              82
# 50      0.99        9.99        1   90.090090              77
# 51      3.99       29.99        1   86.695565              81
# 52      2.49       24.99        1   90.036014              78
# 53      0.89        8.99        1   90.100111              79
# 54      0.99        9.99        1   90.090090              79
# 55      0.99        9.99        1   90.090090              79
# 56      1.99       19.99        1   90.045023              77
# 57     17.10       89.99        1   80.997889               0
# 58      1.09        9.99        1   89.089089              80
# 59      0.99        9.99        1   90.090090              76
#
#     steamRatingText steamRatingPercent steamRatingCount steamAppID  \
# 0     Very Positive                 93              357    1031460
# 1              None                  0                0       None
# 2              None                  0                0       None
# 3              None                  0                0       None
# 4              None                  0                0       None
# 5     Very Positive                 93            80374     632470
# 6              None                  0                0       None
# 7              None                  0                0       None
# 8              None                  0                0       None
# 9              None                  0                0       None
# 10             None                  0                0       None
# 11    Very Positive                 92            22350     238010
# 12             None                  0                0       None
# 13             None                  0                0       None
# 14    Very Positive                 93            80374     632470
# 15    Very Positive                 93            80374     632470
# 16             None                  0                0       None
# 17             None                  0                0       None
# 18             None                  0                0       None
# 19    Very Positive                 96              141    1471960
# 20    Very Positive                 86            13795     627270
# 21             None                  0                0       None
# 22    Very Positive                 94             1580     211740
# 23    Very Positive                 87              463     638000
# 24    Very Positive                 90             8823      45760
# 25             None                  0                0       None
# 26  Mostly Positive                 73              125     332250
# 27    Very Positive                 87              463     638000
# 28    Very Positive                 87              463     638000
# 29    Very Positive                 91             2011     376300
# 30             None                  0                0       None
# 31             None                  0                0       None
# 32  Mostly Positive                 77              798     420060
# 33    Very Positive                 90              277     223730
# 34    Very Positive                 90             8823      45760
# 35             None                  0                0       None
# 36             None                  0                0       None
# 37             None                  0                0       None
# 38    Very Positive                 92              426     390720
# 39    Very Positive                 88               90    1051410
# 40    Very Positive                 90             8823      45760
# 41    Very Positive                 90             8823      45760
# 42    Very Positive                 80              763     496620
# 43  Mostly Positive                 79            26537     612880
# 44    Very Positive                 92            22350     238010
# 45    Very Positive                 87              332     866190
# 46             None                  0                0       None
# 47    Very Positive                 93             1382     274350
# 48  Mostly Positive                 76              733    1101360
# 49    Very Positive                 90             8823      45760
# 50    Very Positive                 84             1633     249590
# 51    Very Positive                 89            29656     367500
# 52  Mostly Positive                 73              211     370870
# 53    Very Positive                 91             1730     538070
# 54    Very Positive                 94             1891     253030
# 55    Very Positive                 85              261     700160
# 56    Very Positive                 87              987     493540
# 57             None                  0                0       None
# 58    Very Positive                 85              896      91200
# 59    Very Positive                 84             1559     247240
#
#     releaseDate  lastChange dealRating  \
# 0    1671580800  1704995897       10.0
# 1             0  1705277354       10.0
# 2             0  1704889637       10.0
# 3             0  1705405727       10.0
# 4             0  1705405727       10.0
# 5    1617062400  1705486413       10.0
# 6             0  1705315851       10.0
# 7             0  1705277271       10.0
# 8             0  1705494147       10.0
# 9             0  1705482900       10.0
# 10            0  1705482893       10.0
# 11   1382400000  1705318491        9.9
# 12            0  1705277271        9.9
# 13            0  1705277258        9.9
# 14   1617062400  1705454333        9.9
# 15   1617062400  1705456512        9.9
# 16            0  1705482894        9.9
# 17            0  1705482893        9.9
# 18            0  1705277271        9.8
# 19   1735603200  1705346988        9.8
# 20   1512000000  1705313571        9.8
# 21            0  1705274922        9.7
# 22    951782400  1705318499        9.7
# 23   1548201600  1705491553        9.7
# 24   1407369600  1705487394        9.6
# 25            0  1705277352        9.6
# 26   1421798400  1705400881        9.6
# 27   1548201600  1705489357        9.6
# 28   1548201600  1705489332        9.6
# 29   1449619200  1705487959        9.5
# 30            0  1704889672        9.5
# 31            0  1704966893        9.5
# 32   1478822400  1705415843        9.5
# 33   1352419200  1705400825        9.5
# 34   1407369600  1705453245        9.5
# 35            0  1705277360        9.4
# 36            0  1705482894        9.4
# 37            0  1704889672        9.4
# 38   1468281600  1705400912        9.4
# 39   1569456000  1705400717        9.4
# 40   1407369600  1705486896        9.4
# 41   1407369600  1705461107        9.4
# 42   1490227200  1705346952        9.4
# 43   1509062400  1705316137        9.3
# 44   1382400000  1705070155        9.3
# 45   1557964800  1705329404        9.3
# 46            0  1704922522        9.3
# 47   1441843200  1705329470        9.3
# 48   1595289600  1705315980        9.3
# 49   1407369600  1705310296        9.3
# 50   1386892800  1705415880        9.3
# 51   1452816000  1705487361        9.3
# 52   1626739200  1705400904        9.3
# 53   1489017600  1705345272        9.3
# 54   1376870400  1705329490        9.3
# 55   1532390400  1705326855        9.3
# 56   1506038400  1705400949        9.2
# 57            0  1704922536        9.2
# 58   1302220800  1705347051        9.2
# 59   1379030400  1705415882        9.2
#
#                                                 thumb
# 0   https://cdn.cloudflare.steamstatic.com/steam/a...
# 1   https://hb.imgix.net/99ac330cd8194385c47c92209...
# 2   https://images.greenmangaming.com/f1dbed643b8f...
# 3   https://sttc.gamersgate.com/images/product/bac...
# 4   https://sttc.gamersgate.com/images/product/bac...
# 5   https://cdn.cloudflare.steamstatic.com/steam/a...
# 6   https://images.greenmangaming.com/478bffac6317...
# 7   https://images.greenmangaming.com/85f64a5bdd20...
# 8   https://images.greenmangaming.com/943fe15861a1...
# 9   https://hb.imgix.net/5fa544ab5435535c247224d10...
# 10  https://store.ubisoft.com/dw/image/v2/ABBS_PRD...
# 11  https://cdn.cloudflare.steamstatic.com/steam/a...
# 12  https://images.greenmangaming.com/b0279bf8df8a...
# 13  https://images.greenmangaming.com/e6797d37de12...
# 14  https://cdn.cloudflare.steamstatic.com/steam/a...
# 15  https://cdn.cloudflare.steamstatic.com/steam/a...
# 16  https://store.ubisoft.com/dw/image/v2/ABBS_PRD...
# 17  https://images.greenmangaming.com/5586046eb67a...
# 18  https://images.greenmangaming.com/5586046eb67a...
# 19  https://cdn.cloudflare.steamstatic.com/steam/a...
# 20  https://cdn.cloudflare.steamstatic.com/steam/a...
# 21  https://sttc.gamersgate.com/images/product/ego...
# 22  https://cdn.cloudflare.steamstatic.com/steam/a...
# 23  https://cdn.cloudflare.steamstatic.com/steam/a...
# 24  https://cdn.cloudflare.steamstatic.com/steam/a...
# 25  https://images.greenmangaming.com/760a3a77cfb4...
# 26  https://cdn.cloudflare.steamstatic.com/steam/a...
# 27  https://cdn.cloudflare.steamstatic.com/steam/a...
# 28  https://cdn.cloudflare.steamstatic.com/steam/a...
# 29  https://cdn.cloudflare.steamstatic.com/steam/a...
# 30  https://www.indiegalacdn.com/get_store_img?img...
# 31  https://sttc.gamersgate.com/images/product/got...
# 32  https://cdn.cloudflare.steamstatic.com/steam/a...
# 33  https://cdn.cloudflare.steamstatic.com/steam/a...
# 34  https://cdn.cloudflare.steamstatic.com/steam/a...
# 35  https://hb.imgix.net/55aeda639e1c330e90ff6c622...
# 36  https://images.greenmangaming.com/7ddf07c794a6...
# 37  https://www.indiegalacdn.com/get_store_img?img...
# 38  https://cdn.cloudflare.steamstatic.com/steam/a...
# 39  https://cdn.cloudflare.steamstatic.com/steam/a...
# 40  https://cdn.cloudflare.steamstatic.com/steam/a...
# 41  https://cdn.cloudflare.steamstatic.com/steam/a...
# 42  https://cdn.cloudflare.steamstatic.com/steam/a...
# 43  https://cdn.cloudflare.steamstatic.com/steam/a...
# 44  https://cdn.cloudflare.steamstatic.com/steam/a...
# 45  https://cdn.cloudflare.steamstatic.com/steam/a...
# 46  https://sttc.gamersgate.com/images/product/got...
# 47  https://cdn.cloudflare.steamstatic.com/steam/a...
# 48  https://cdn.cloudflare.steamstatic.com/steam/a...
# 49  https://cdn.cloudflare.steamstatic.com/steam/a...
# 50  https://cdn.cloudflare.steamstatic.com/steam/a...
# 51  https://cdn.cloudflare.steamstatic.com/steam/a...
# 52  https://cdn.cloudflare.steamstatic.com/steam/a...
# 53  https://cdn.cloudflare.steamstatic.com/steam/a...
# 54  https://cdn.cloudflare.steamstatic.com/steam/a...
# 55  https://cdn.cloudflare.steamstatic.com/steam/a...
# 56  https://cdn.cloudflare.steamstatic.com/steam/a...
# 57  https://sttc.gamersgate.com/images/product/bac...
# 58  https://cdn.cloudflare.steamstatic.com/steam/a...
# 59  https://cdn.cloudflare.steamstatic.com/steam/a...

# %% [markdown]
# - Cek summary data dan cek shape dari data yang dimiliki

# %%
rawGameDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   internalName        60 non-null     object
#  1   title               60 non-null     object
#  2   metacriticLink      37 non-null     object
#  3   dealID              60 non-null     object
#  4   storeID             60 non-null     object
#  5   gameID              60 non-null     object
#  6   salePrice           60 non-null     object
#  7   normalPrice         60 non-null     object
#  8   isOnSale            60 non-null     object
#  9   savings             60 non-null     object
#  10  metacriticScore     60 non-null     object
#  11  steamRatingText     37 non-null     object
#  12  steamRatingPercent  60 non-null     object
#  13  steamRatingCount    60 non-null     object
#  14  steamAppID          37 non-null     object
#  15  releaseDate         60 non-null     int64
#  16  lastChange          60 non-null     int64
#  17  dealRating          60 non-null     object
#  18  thumb               60 non-null     object
# dtypes: int64(2), object(17)
# memory usage: 9.0+ KB

# %%
rawGameDataFrame.shape
# Out:
# (60, 19)

# %% [markdown]
# - Lakukan proses select data dengan kolom berikut:
#     - `title`
#     - `storeID`
#     - `gameID`
#     - `salePrice`
#     - `normalPrice`
#     - `steamRatingText`
#     - `steamRatingCount`
#     - `releaseDate`
#     - `lastChange`
#
# - Simpan ke dalam variable baru

# %%
SELECTED_COLS = [
    'title',
    'storeID',
    'gameID',
    'salePrice',
    'normalPrice',
    'steamRatingText',
    'steamRatingCount',
    'releaseDate',
    'lastChange'
]
selectedGameDataFrame = rawGameDataFrame[SELECTED_COLS]

# %% [markdown]
# - Lakukan process slicing data yang dimulai dari index `1` sampai index ke `40`
# - Setelah itu simpan ke dalam variable baru

# %%
truncatedGameDataFrame = selectedGameDataFrame[1:41]

# %% [markdown]
# - Lakukan proses rename column seperti berikut:
#     - `storeID`: `store_id`
#     - `gameID`: `game_id`
#     - `salePrice`: `sale_price`
#     - `normalPrice`: `normal_price`
#     - `steamRatingText`: `steam_rating_text`
#     - `steamRatingCount`: `steam_rating_count`
#     - `releaseDate`: `release_date`
#     - `lastChange`: `last_change`

# %%
RENAME_COLS = {
    'storeID' : 'store_id',
    'gameID' : 'game_id',
    'salePrice' : 'sale_price',
    'normalPrice' : 'normal_price',
    'steamRatingText' : 'steam_rating_text',
    'steamRatingCount' : 'steam_rating_count',
    'releaseDate' : 'release_date',
    'lastChange' : 'last_change'
}
gameDataFrame = truncatedGameDataFrame.rename(columns = RENAME_COLS)

# %% [markdown]
# - Terdapat datetime data pada kolom `release_date` dan `last_change`
# - Jika dilihat, data tersebut dalam format **Unix Epoch** atau **Unix Time**
#
# <center>
#
# <img src="https://www.researchgate.net/profile/Youssef-Iraqi-2/publication/348760440/figure/fig5/AS:984164266438656@1611654454716/Unix-Epoch-Time-format-and-corresponding-time-and-date.png" width=300px;>
#
# [img source](https://www.researchgate.net/profile/Youssef-Iraqi-2/publication/348760440/figure/fig5/AS:984164266438656@1611654454716/Unix-Epoch-Time-format-and-corresponding-time-and-date.png)
#
# </center>
#
# - Ubahlah data tersebut menjadi bentuk timestamp
# - Untuk mengubahnya kita membutuhkan function **`pd.to_datetime()`**, untuk detail nya bisa langsung mengecek [dokumentasi pandas](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html)

# %%
gameDataFrame['release_date'] = (
    pd.to_datetime(gameDataFrame['release_date'], unit = 's')
)
gameDataFrame['last_change'] = (
    pd.to_datetime(gameDataFrame['last_change'], unit = 's')
)

# %% [markdown]
# - Casting data type `sale_price` dan `normal_price` dari `object` menjadi `float`

# %%
CAST_COLS = {
    'sale_price' : 'float',
    'normal_price' : 'float'
}
gameDataFrame = gameDataFrame.astype(CAST_COLS)
gameDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 1 to 40
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               40 non-null     object
#  1   store_id            40 non-null     object
#  2   game_id             40 non-null     object
#  3   sale_price          40 non-null     float64
#  4   normal_price        40 non-null     float64
#  5   steam_rating_text   19 non-null     object
#  6   steam_rating_count  40 non-null     object
#  7   release_date        40 non-null     datetime64[ns]
#  8   last_change         40 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(5)
# memory usage: 2.9+ KB

# %% [markdown]
# - Lakukan proses filter yang game memiliki rating `Mostly Positive` dan memiliki harga diskon kurang dari sama dengan `25.5`

# %%
filteredGameDataFrame = (
    gameDataFrame[
        (gameDataFrame['steam_rating_text'] == 'Mostly Positive') &
        (gameDataFrame['sale_price'] <= 25.5)
    ]
)
filteredGameDataFrame
# Out:
#                 title store_id game_id  sale_price  normal_price  \
# 26  The Next Penelope       30  141090        1.29         12.99
# 32             Candle        7  155405        0.99          9.99
#
#    steam_rating_text steam_rating_count release_date         last_change
# 26   Mostly Positive                125   2015-01-21 2024-01-16 10:28:01
# 32   Mostly Positive                798   2016-11-11 2024-01-16 14:37:23

# %% [markdown]
# - Buatlah table PostgreSQL baru dengan nama `games_listing` dengan schema berikut
#
# ```sql
# CREATE TABLE public.games_listing (
# 	title varchar NULL,
# 	store_id int NULL,
# 	game_id int NULL,
# 	sale_price numeric NULL,
# 	normal_price numeric NULL,
# 	steam_rating_text varchar NULL,
# 	steam_rating_count int NULL,
# 	release_date timestamp NULL,
# 	last_change timestamp NULL
# );
# ```
#
# ![Tabel games_listing](data/Screenshot%202024-01-17%20213908.png)

# %% [markdown]
# - Buatlah koneksi untuk menyambungkan database dengan pandas

# %%
from sqlalchemy import create_engine

# create connection with postgres
conn = create_engine("postgresql://postgres:auliya01@localhost/db_games_listing")

# %% [markdown]
# - Masukkan data terakhir ke dalam table `games_listing`

# %%
filteredGameDataFrame.to_sql(
    name = "games_listing", 
    con = conn,
    if_exists = "append", 
    index = False
)
# Out:
# 2

# %% [markdown]
# - Sekarang cek apakah data sudah masuk ke dalam database dengan menggunakan pandas

# %%
query = f"""
SELECT * FROM games_listing
"""
checkDataFrame = pd.read_sql(query, con = conn)
checkDataFrame
# Out:
#                title  store_id  game_id  sale_price  normal_price  \
# 0  The Next Penelope        30   141090        1.29         12.99
# 1             Candle         7   155405        0.99          9.99
#
#   steam_rating_text  steam_rating_count release_date         last_change
# 0   Mostly Positive                 125   2015-01-21 2024-01-16 10:28:01
# 1   Mostly Positive                 798   2016-11-11 2024-01-16 14:37:23
