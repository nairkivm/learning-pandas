# %%
# Import packages
import pandas as pd
from sqlalchemy import create_engine

# %%
# create connection with postgres
conn = create_engine("postgresql://postgres:auliya01@localhost/pagila")

# %%
query = "SELECT * FROM film"

rentalDataFrame = pd.read_sql(sql = query, con = conn)

rentalDataFrame
# Out:
#      film_id              title  \
# 0        133    Chamber Italian
# 1        384   Grosse Wonderful
# 2          8    Airport Pollock
# 3         98  Bright Encounters
# 4          1   Academy Dinosaur
# ..       ...                ...
# 995      996     Young Language
# 996      997         Youth Kick
# 997      998       Zhivago Core
# 998      999  Zoolander Fiction
# 999     1000          Zorro Ark
#
#                                            description  release_year  \
# 0    A Fateful Reflection of a Moose And a Husband ...          2006
# 1    A Epic Drama of a Cat And a Explorer who must ...          2006
# 2    A Epic Tale of a Moose And a Girl who must Con...          2006
# 3    A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4    A Epic Drama of a Feminist And a Mad Scientist...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %% [markdown]
# - Langkah selanjutnya adalah select kolom - kolom berikut:
#     - `film_id`
#     - `title`
#     - `release_year`
#     - `rental_rate`
#     - `length`
#     - `rating`
#     - `last_update`

# %%
rentalDataFrameColumns = [
    'film_id', 
    'title',
    'release_year',
    'rental_rate',
    'length',
    'rating',
    'last_update'
]

rentalDataFrame = rentalDataFrame[rentalDataFrameColumns]

rentalDataFrame
# Out:
#      film_id              title  release_year  rental_rate  length rating  \
# 0        133    Chamber Italian          2006         4.99     117  NC-17
# 1        384   Grosse Wonderful          2006         4.99      49      R
# 2          8    Airport Pollock          2006         4.99      54      R
# 3         98  Bright Encounters          2006         4.99      73  PG-13
# 4          1   Academy Dinosaur          2006         0.99      86     PG
# ..       ...                ...           ...          ...     ...    ...
# 995      996     Young Language          2006         0.99     183      G
# 996      997         Youth Kick          2006         0.99     179  NC-17
# 997      998       Zhivago Core          2006         0.99     105  NC-17
# 998      999  Zoolander Fiction          2006         2.99     101      R
# 999     1000          Zorro Ark          2006         4.99      50  NC-17
#
#                 last_update
# 0   2013-05-26 14:50:58.951
# ...

# %% [markdown]
# - Sebelum melakukan filter data, coba cek bagaimana value yang ada di kolom `rating`

# %%
rentalDataFrame['rating'].value_counts()
# Out:
# rating
# PG-13    223
# NC-17    210
# R        195
# PG       194
# G        178
# Name: count, dtype: int64

# %% [markdown]
# - Berdasarkan data tersebut, lakukanlah filter data yang dimana rating memiliki value `PG` dan memiliki durasi yang lebih dari sama dengan `90`

# %%
filteredRentalDataFrame = (
    rentalDataFrame[
        (rentalDataFrame['rating'] == 'PG') & 
        (rentalDataFrame['length'] >= 90) 
    ]
)
filteredRentalDataFrame
# Out:
#      film_id                 title  release_year  rental_rate  length rating  \
# 9          6          Agent Truman          2006         2.99     169     PG
# 14        12        Alaska Phantom          2006         0.99     136     PG
# 16        13           Ali Forever          2006         4.99     150     PG
# 22        19          Amadeus Holy          2006         0.99     113     PG
# 40        37          Arizona Bang          2006         2.99     121     PG
# ..       ...                   ...           ...          ...     ...    ...
# 954      955          Walls Artist          2006         4.99     135     PG
# 982      983             Won Dares          2006         2.99     105     PG
# 984      985  Wonderland Christmas          2006         4.99     111     PG
# 986      987          Words Hunter          2006         2.99     116     PG
# 990      991          Worst Banger          2006         2.99     185     PG
#
#                 last_update
# ...

# %% [markdown]
# - Simpan data terbaru tersebut ke file baru dengan nama `new_rental_data.csv` tanpa menggunakan index dari data sebelumnya

# %%
filteredRentalDataFrame.to_csv('data/new_rental_data.csv', index=False)

newRentalDataFrame = pd.read_csv('data/new_rental_data.csv')
newRentalDataFrame
# Out:
#      film_id                 title  release_year  rental_rate  length rating  \
# 0          6          Agent Truman          2006         2.99     169     PG
# 1         12        Alaska Phantom          2006         0.99     136     PG
# 2         13           Ali Forever          2006         4.99     150     PG
# 3         19          Amadeus Holy          2006         0.99     113     PG
# 4         37          Arizona Bang          2006         2.99     121     PG
# ..       ...                   ...           ...          ...     ...    ...
# 127      955          Walls Artist          2006         4.99     135     PG
# 128      983             Won Dares          2006         2.99     105     PG
# 129      985  Wonderland Christmas          2006         4.99     111     PG
# 130      987          Words Hunter          2006         2.99     116     PG
# 131      991          Worst Banger          2006         2.99     185     PG
#
#                  last_update
# ...
